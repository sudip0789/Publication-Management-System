# %% [markdown]
# # Stanford Law Faculty Publications: Prototype System
#
# ### Sudip Das
# ### Last Updated: 11 Dec, 2025

# %%
import pandas as pd
import numpy as np
import re
import os
from openai import OpenAI
from google.colab import userdata
import json
import requests

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file_path = "/content/drive/My Drive/Stanford/Faculty Publications-Grid view.csv"

df = pd.read_csv(file_path)
df.head()
# Out:
#          ID Faculty Contributor Faculty Co-Authors/Editors      Co-Authors  \
# 0  500784.0   Ablavsky, Gregory                        NaN             NaN
# 1  513224.0   Ablavsky, Gregory                        NaN  Felix S. Cohen
# 2  493786.0   Ablavsky, Gregory                        NaN             NaN
# 3  437598.0   Ablavsky, Gregory                        NaN             NaN
# 4  407547.0   Ablavsky, Gregory                        NaN             NaN
#
#                                                Title        Publication Type  \
# 0  Speculation Nation: Land Mania in the Revoluti...             Book Review
# 1             Cohen's Handbook of Federal Indian Law             Book, Whole
# 2  The Original Meaning of Commerce in the Indian...         Journal Article
# 3  Clarence Thomas Went After My Work. His Critic...  Op-Ed or Opinion Piece
# 4                         Akhil Amar's Unusable Past             Book Review
#
#   Contribution        Date    Year     Status  ... ISSN  \
# 0       Writer     2024-12  2024.0  Published  ...  NaN
# 1       Editor     2024-10  2024.0  Published  ...  NaN
# 2       Writer        2024  2024.0  Published  ...  NaN
# 3       Writer  2023-06-20  2023.0  Published  ...  NaN
# 4       Writer        2023  2023.0  Published  ...  NaN
#
#                                             Abstract  \
# 0                                                NaN
# 1                                                NaN
# 2  In Haaland v. Brackeen, the Supreme Court retu...
# 3  If judges are going to use history as their gu...
# 4                                                NaN
#
#                                       Source Link(s)  \
# 0                                                NaN
# 1  https://store.lexisnexis.com/en-us/products/co...
# 2                                                NaN
# 3  https://slate.com/news-and-politics/2023/06/cl...
# 4                                                NaN
#
#                                        Stanford Link  DOI PURL SSRN In ORCID  \
# 0  https://law.stanford.edu/publications/speculat...  NaN  NaN  NaN      NaN
# 1  https://law.stanford.edu/publications/cohens-h...  NaN  NaN  NaN      NaN
# 2  https://law.stanford.edu/publications/the-orig...  NaN  NaN  NaN      NaN
# 3  https://law.stanford.edu/publications/clarence...  NaN  NaN  NaN      NaN
# 4  https://law.stanford.edu/publications/akhil-am...  NaN  NaN  NaN      NaN
#
#   Corrected Designation
# 0   checked     Faculty
# 1   checked     Faculty
# 2   checked     Faculty
# 3   checked     Faculty
# 4   checked     Faculty
#
# [5 rows x 31 columns]

# %%
print("Shape (rows, columns):", df.shape)
print(df.columns.tolist())
# Out:
# Shape (rows, columns): (1927, 31)
# ['ID', 'Faculty Contributor', 'Faculty Co-Authors/Editors', 'Co-Authors', 'Title', 'Publication Type', 'Contribution', 'Date', 'Year', 'Status', 'Serial Title', 'Publisher', 'Publication Title', 'Editor(s)', 'Citation', 'Italics', 'Volume', 'Issue', 'Pages', 'Edition', 'ISBN', 'ISSN', 'Abstract', 'Source Link(s)', 'Stanford Link', 'DOI', 'PURL', 'SSRN', 'In ORCID', 'Corrected', 'Designation']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1927 entries, 0 to 1926
# Data columns (total 31 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          1926 non-null   float64
#  1   Faculty Contributor         1927 non-null   object
#  2   Faculty Co-Authors/Editors  96 non-null     object
#  3   Co-Authors                  560 non-null    object
#  4   Title                       1927 non-null   object
#  5   Publication Type            1927 non-null   object
#  6   Contribution                1699 non-null   object
#  7   Date                        1927 non-null   object
#  8   Year                        1926 non-null   float64
#  9   Status                      1316 non-null   object
#  10  Serial Title                1440 non-null   object
#  11  Publisher                   1680 non-null   object
#  12  Publication Title           251 non-null    object
#  13  Editor(s)                   127 non-null    object
#  14  Citation                    1926 non-null   object
#  15  Italics                     985 non-null    object
#  16  Volume                      657 non-null    object
#  17  Issue                       237 non-null    object
#  18  Pages                       686 non-null    object
#  19  Edition                     36 non-null     object
#  20  ISBN                        22 non-null     float64
#  21  ISSN                        1 non-null      object
#  22  Abstract                    560 non-null    object
#  23  Source Link(s)              1155 non-null   object
#  24  Stanford Link               1926 non-null   object
#  25  DOI                         43 non-null     object
#  26  PURL                        0 non-null      float64
#  27  SSRN                        0 non-null      float64
#  28  In ORCID                    68 non-null     object
#  29  Corrected                   985 non-null    object
#  30  Designation                 1927 non-null   object
# dtypes: float64(5), object(26)
# memory usage: 466.8+ KB

# %%
display(df.describe(include=['object']).T)
# Out:
#                            count unique  \
# Faculty Contributor         1927     87
# Faculty Co-Authors/Editors    96     28
# Co-Authors                   560    409
# Title                       1927   1741
# Publication Type            1927     13
# Contribution                1699      3
# Date                        1927    911
# Status                      1316      2
# Serial Title                1440    488
# Publisher                   1680    328
# Publication Title            251    211
# Editor(s)                    127     98
# Citation                    1926   1833
# Italics                      985      1
# Volume                       657    204
# Issue                        237     34
# Pages                        686    557
# Edition                       36     19
# ISSN                           1      1
# Abstract                     560    532
# Source Link(s)              1155   1078
# Stanford Link               1926   1785
# DOI                           43     37
# In ORCID                      68      1
# Corrected                    985      1
# Designation                 1927      5
#
#                                                                           top  \
# Faculty Contributor                                        Mello, Michelle M.
# Faculty Co-Authors/Editors                          "Engstrom, David Freeman"
# Co-Authors                    Nicholson Price; Rachel Sachs; Jacob S. Sherkow
# Title                       Stanford Law Faculty on the Historic Confirmat...
# Publication Type                                              Journal Article
# Contribution                                                           Writer
# Date                                                                     2023
# Status                                                              Published
# Serial Title                                         Written Description Blog
# Publisher                                                 Stanford Law School
# Publication Title                  Legal Tech and the Future of Civil Justice
# Editor(s)                                              David Freeman Engstrom
# Citation                    <span style="font-weight: 400">Ralph Richard B...
# Italics                                                               checked
# Volume                                                                      2
# Issue                                                                       2
# Pages                                                                       1
# Edition                                                                   3rd
# ISSN                                                                1537-5366
# Abstract                    Since many large, state-owned Intermediate Car...
# Source Link(s)              https://law.stanford.edu/2022/04/08/stanford-l...
# Stanford Link               https://law.stanford.edu/publications/stanford...
# DOI                                     https://doi.org/10.1017/9781009255301
# In ORCID                                                              checked
# Corrected                                                             checked
# Designation                                                           Faculty
#
#                             freq
# Faculty Contributor          116
# Faculty Co-Authors/Editors    15
# Co-Authors                    15
# Title                          7
# Publication Type             895
# Contribution                1688
# Date                          84
# Status                      1279
# Serial Title                  45
# Publisher                    114
# Publication Title              7
# Editor(s)                      9
# Citation                       6
# Italics                      985
# Volume                        14
# Issue                         51
# Pages                         28
# Edition                        5
# ISSN                           1
# Abstract                       2
# Source Link(s)                 7
# Stanford Link                  7
# DOI                            6
# In ORCID                      68
# Corrected                    985
# Designation                 1647

# %% [markdown]
# ### Initial data profile – key observations
#
# **Size & structure**: 1,927 rows, 31 columns. Mostly object (string) columns; a few numeric fields
#
# **Quality**: Few columns such as Title, Faculty Contributor is complete while columns such as ISSN, DOI and Edition are missing most of the data. The goal would be to check whether these can be collected from other sources or missing from the original source.
#
# **ID**: This will be the key to query or retrieve any publications however there is one missing value

# %%
df['ID'].isna().sum()
# Out:
# np.int64(1)

# %%
df['ID'].nunique()
# Out:
# 1786

# %% [markdown]
# ## Standardizing Names
#
# Name format: Last Name, First Name for Faculty Contributor
#
# Faculty Co-Authors/Editors in quotations to separate multiple names
#
# Co-Authors are separated by colon and wrote in First name Last Name
#
# Names should have consistent format
#
# the same person might be referred in different ways across entries (middle initials, accent marks in names, etc.), requiring normalization or having a separate column such as Batch ID if Stanford has something similar

# %%
#Standardizing faculty Co-Authors/Editors column
df['Faculty Co-Authors/Editors'] = (
    df['Faculty Co-Authors/Editors']
      .str.replace(r'"\s*,\s*"', '; ', regex=True)
      .str.replace('"', '', regex=False)
      .str.strip()
)
df[df['Faculty Co-Authors/Editors'].notna()]['Faculty Co-Authors/Editors'].head(10)
# Out:
# 10                              Reese, Elizabeth Hidalgo
# 35                             Ouellette, Lisa Larrimore
# 65                                Ford, Richard Thompson
# 78                                        Sykes, Alan O.
# 81                                        Fried, Barbara
# 87     McConnell, Michael W.; Gould IV, William B.; S...
# 279                               Engstrom, Nora Freeman
# 280                               Engstrom, Nora Freeman
# 284                               Engstrom, Nora Freeman
# 285                               Engstrom, Nora Freeman
# Name: Faculty Co-Authors/Editors, dtype: object

# %%
# Standardizing Co-Authors and Editors column
def transform_name_first_last(name: str) -> str:
    """
    Transform 'First Middle Last' -> 'Last, First Middle'
    """
    if not isinstance(name, str):
        return name

    name = name.strip()
    if not name:
        return name

    parts = name.split()
    if len(parts) == 1:
        return name

    last = parts[-1]
    first_middle = ' '.join(parts[:-1])
    return f"{last}, {first_middle}"


def normalize_coauthors(value: str, separators_pattern: str) -> str:
    """
    Split an author string on the given separators pattern,
    normalize each name as 'Last, First', and join with '; '.
    """
    if pd.isna(value) or not str(value).strip():
        return value

    text = str(value).strip()

    # Split on the provided separators (e.g. ';' or '[;,]')
    authors = re.split(separators_pattern, text)
    authors = [a.strip() for a in authors if a.strip()]

    transformed = [transform_name_first_last(a) for a in authors]
    return '; '.join(transformed)

# Co-Authors: authors separated by ';'
df["Co-Authors"] = df["Co-Authors"].apply(
    lambda s: normalize_coauthors(s, r';')
)

# Editor(s): authors separated by ';' OR ','
df["Editor(s)"] = df["Editor(s)"].apply(
    lambda s: normalize_coauthors(s, r'[;,]')
)


print(df["Co-Authors"].dropna().head(5))

print(df["Editor(s)"].dropna().head(5))
# Out:
# 1                   Cohen, Felix S.
# 7                Allread, W. Tanner
# 30    Deer, Sarah; Richland, Justin
# 42               Sirleaf, Matiangai
# 43                   McDougall, Gay
# Name: Co-Authors, dtype: object
# 1                 Berger, Bethany R.; Blackhawk, Maggie
# 30    Stern, Simon; Mar, Maksymilian Del; Meyler, Be...
# 37                                     Chetail, Vincent
# 38                                     Chetail, Vincent
# 46    Binder, Christina; Nowak, Manfred; Hofbauer, J...
# Name: Editor(s), dtype: object

# %%
# Validation checks
print(df["Co-Authors"].dropna().head(10))

print(df["Editor(s)"].dropna().head(10))
# Out:
# 1                   Cohen, Felix S.
# 7                Allread, W. Tanner
# 30    Deer, Sarah; Richland, Justin
# 42               Sirleaf, Matiangai
# 43                   McDougall, Gay
# 44               Gathii, James Thuo
# 46                      Lake, Diane
# 47                 Devakumar, Delan
# 51                     Last, Tamara
# 53                       Bâli, Aslı
# Name: Co-Authors, dtype: object
# 1                  Berger, Bethany R.; Blackhawk, Maggie
# 30     Stern, Simon; Mar, Maksymilian Del; Meyler, Be...
# 37                                      Chetail, Vincent
# 38                                      Chetail, Vincent
# 46     Binder, Christina; Nowak, Manfred; Hofbauer, J...
# 56     Costello, Cathryn; Foster, Michelle; McAdam, Jane
# 84                  Grossman, Joanna L.; Kim, Suzanne A.
# 93           Fontenay, Elisabeth D. de; Broughman, Brian
# 94                               Cumming, D.; Hammer, B.
# 100          Fontenay, Elisabeth D. de; Broughman, Brian
# Name: Editor(s), dtype: object

# %% [markdown]
# ## Normalizating Text/String fields

# %%
import html
import unicodedata
def clean_text_basic(text: str) -> str:
    """
    Basic text normalization:
    - Handle NaN safely
    - Strip leading/trailing whitespace
    - Remove HTML tags
    - Unescape HTML entities
    - Normalize unicode (NFKC)
    - Normalize quotes/dashes
    - Collapse multiple spaces
    """
    if pd.isna(text):
        return text

    s = str(text)

    s = s.strip()# Strip outer whitespace
    s = re.sub(r"<[^>]+>", "", s) # Remove HTML tags

    s = html.unescape(s)
    s = unicodedata.normalize("NFKC", s)

    # Normalize curly quotes and dashes to simpler forms
    replacements = {
        "“": '"',
        "”": '"',
        "‘": "'",
        "’": "'",
        "–": "-",   # en dash
        "—": "-",   # em dash
        "\u00a0": " ",  # non-breaking space
    }
    for old, new in replacements.items():
        s = s.replace(old, new)
    s = re.sub(r"\s+", " ", s)

    return s

# %%
text_cols = [
    "Title",
    "Serial Title",
    "Publisher",
    "Publication Title",
    "Citation",
]

for col in text_cols:
    df[col] = df[col].apply(clean_text_basic)

# Quick before/after check on a few rows
df[["Title", "Publisher", "Citation",]].head(30)
# Out:
#                                                 Title  \
# 0   Speculation Nation: Land Mania in the Revoluti...
# 1              Cohen's Handbook of Federal Indian Law
# 2   The Original Meaning of Commerce in the Indian...
# 3   Clarence Thomas Went After My Work. His Critic...
# 4                          Akhil Amar's Unusable Past
# 5   Book Review, Creek Internationalism in an Age ...
# 6   Too Much History: Castro-Huerta and the Proble...
# 7   We the (Native) People?: How Indigenous People...
# 8   Getting Public Rights Wrong: The Lost History ...
# 9   Oklahoma's Bizarro Nineteenth Century in Castr...
# 10  The Supreme Court Strikes Again - This Time at...
# 11  Beyond the Indian Commerce Clause: Robert Nate...
# 12  Joe Manchin is wrong - D.C. statehood is const...
# 13                                        Book Review
# 14  Are Alaska Native Corporations Indian Tribes? ...
# 15  The Dark History of Indigenous Dispossession t...
# 16  Justices argue over text (and ceviche) in ruli...
# 17  Federal Ground: Governing Property and Violenc...
# 18  Credit Nation: Property Laws and Institutions ...
# 19  McGirt: Gorsuch Affirms "Rule of Law," Not "Ru...
# 20  Murder in the Shenandoah: Making Law Sovereign...
# 21  Of One Mind and of One Government: The Rise an...
# 22             Inside the JAH: Species of Sovereignty
# 23  Brief of Amici Curiae Historians, Legal Schola...
# 24  Brackeen, the Indian Child Welfare Act, and th...
# 25  Stanford's Greg Ablavsky on Law and the Histor...
# 26  Argument analysis: Justices Grapple with Precl...
# 27  Species of Sovereignty: Native Nationhood, the...
# 28       Empire States: The Coming of Dual Federalism
# 29  Administrative Constitutionalism and the North...
#
#                                             Publisher  \
# 0                             Oxford University Press
# 1                                          LexisNexis
# 2             University of Connecticut School of Law
# 3                                     Graham Holdings
# 4                   University of Michigan Law School
# 5   The University of North Carolina Press,Univers...
# 6                         University of Chicago Press
# 7                                 Columbia Law School
# 8                                 Stanford Law School
# 9                                 Stanford Law School
# 10                                      Nash Holdings
# 11                                Stanford Law School
# 12                                Nexstar Media Group
# 13  Oxford University Press,Organization of Americ...
# 14                             "Dispatch Media, Inc."
# 15                                Stanford Law School
# 16                             "Dispatch Media, Inc."
# 17                            Oxford University Press
# 18                            Oxford University Press
# 19                                Stanford Law School
# 20  The University of North Carolina Press,Society...
# 21  The University of North Carolina Press,Society...
# 22                Organization of American Historians
# 23                                                NaN
# 24                                Stanford Law School
# 25                                Stanford Law School
# 26                             "Dispatch Media, Inc."
# 27  Oxford University Press,Organization of Americ...
# 28               "The Yale Law Journal Company, Inc."
# 29                                     Penn Carey Law
#
#                                              Citation
# 0   Gregory Ablavsky, Speculation Nation: Land Man...
# 1   Fᴇʟɪx S. Cᴏʜᴇɴ, Cᴏʜᴇɴ'ꜱ Hᴀɴᴅʙᴏᴏᴋ ᴏꜰ Fᴇᴅᴇʀᴀʟ Iɴ...
# 2   Gregory Ablavsky, The Original Meaning of Comm...
# 3   Gregory Ablavsky, Clarence Thomas Went After M...
# 4   Gregory Ablavsky, Akhil Amar's Unusable Past, ...
# 5   Gregory Ablavsky, Creek Internationalism in an...
# 6   Gregory Ablavsky, Too Much History: Castro-Hue...
# 7   Gregory Ablavsky & W. Tanner Allread, We the (...
# 8   Gregory Ablavsky, Getting Public Rights Wrong:...
# 9   Gregory Ablavsky, Oklahoma's Bizarro Nineteent...
# 10  Gregory Ablavsky & Elizabeth Hidalgo Reese, Th...
# 11  Gregory Ablavsky, Beyond the Indian Commerce C...
# 12  Gregory Ablavsky, Joe Manchin is Wrong-D.C. St...
# 13  Gregory Ablavsky, Settler Colonialism, Race, a...
# 14  Gregory Ablavsky, Are Alaska Native Corporatio...
# 15  Gregory Ablavsky, The Dark History of Indigeno...
# 16  Gregory Ablavsky, Justices Argue Over Text (an...
# 17  Gʀᴇɢᴏʀʏ Aʙʟᴀᴠꜱᴋʏ, Fᴇᴅᴇʀᴀʟ Gʀᴏᴜɴᴅ: Gᴏᴠᴇʀɴɪɴɢ Pʀ...
# 18  Gregory Ablavsky, Credit Nation: Property Laws...
# 19  Gregory Ablavsky, McGirt: Gorsuch Affirms "Rul...
# 20  Gregory Ablavsky, Murder in the Shenandoah: Ma...
# 21  Gregory Ablavsky, Of One Mind and of One Gover...
# 22  Gregory Ablavsky, Inside the JAH: Species of S...
# 23  Gregory Ablavsky, et al., Brief of Amici Curia...
# 24  Gregory Ablavsky, Brackeen, The Indian Child W...
# 25  Gregory Ablavsky, Stanford's Greg Ablavsky on ...
# 26  Gregory Ablavsky, Argument Analysis: Justices ...
# 27  Gregory Ablavsky, Species of Sovereignty: Nati...
# 28  Gregory Ablavsky, Empire States: The Coming of...
# 29  Gregory Ablavsky, Administrative Constitutiona...

# %%
#Remove Quotations from Publisher
df["Publisher"] = df["Publisher"].apply(
    lambda x: x.replace('"', '').replace("'", '') if isinstance(x, str) else x
)

# %% [markdown]
# ## Extracting Year from Date

# %%
# Take first 4 characters and convert to a year
df["Year"] = pd.to_numeric(
    df["Date"].str.strip().str.slice(0, 4),
    errors="coerce"
).astype("Int64")

#Validation Check
df.loc[df["ID"] == 448166, ["ID", "Faculty Contributor", "Title", "Year", "Date"]]
# Out:
#             ID Faculty Contributor  \
# 1630  448166.0   Sivas, Deborah A.
#
#                                               Title  Year        Date
# 1630  Should We Bring Species Back from Extinction?  2023  2023-06-12

# %% [markdown]
# ## ID Deduplication
#
# Further analysis discovers out of the 1926 IDs, 1786 are unique. This means there are 140 duplicated IDs.
# It is crucial to check whether these are exactly repeated, such as the same publication copied from multiple sources or any presence of errors.
#
# The idea is to delete the exact duplicates where all columns are the same in separate rows and investigate rows with same ID but different data in columns.

# %%
id_counts = df['ID'].value_counts()
dup_ids = id_counts[id_counts > 1].index

print("Number of IDs with more than one row:", len(dup_ids))

dup_df = df[df['ID'].isin(dup_ids)].copy()
print("Number of rows with duplicate IDs:", dup_df.shape[0])
# Out:
# Number of IDs with more than one row: 126
# Number of rows with duplicate IDs: 266

# %%
# Are any duplicate-ID rows completely identical across all columns?
dup_df['is_exact_duplicate'] = dup_df.duplicated(keep=False)

print("Rows that are exact duplicates (same ID, same all fields):")
display(dup_df[dup_df['is_exact_duplicate']].head(10))
# Out:
# Rows that are exact duplicates (same ID, same all fields):
#            ID    Faculty Contributor Faculty Co-Authors/Editors Co-Authors  \
# 127  407567.0            Brest, Paul                        NaN        NaN
# 128  407567.0            Brest, Paul                        NaN        NaN
# 185  407587.0      Daines, Robert M.                        NaN        NaN
# 187  407587.0      Daines, Robert M.                        NaN        NaN
# 450  499949.0  Friedman, Lawrence M.                        NaN        NaN
# 451  499949.0  Friedman, Lawrence M.                        NaN        NaN
# 518  407002.0        Goldstein, Paul                        NaN        NaN
# 519  407002.0        Goldstein, Paul                        NaN        NaN
# 564  500143.0       Greely, Henry T.                        NaN        NaN
# 565  500143.0       Greely, Henry T.                        NaN        NaN
#
#                                                  Title   Publication Type  \
# 127  Processes of Constitutional Decisionmaking: Ca...  Textbook/Casebook
# 128  Processes of Constitutional Decisionmaking: Ca...  Textbook/Casebook
# 185  Recent Developments in Executive Compensation ...      Book, Section
# 187  Recent Developments in Executive Compensation ...      Book, Section
# 450  Freedom of Expression and the Age of the Silve...    Journal Article
# 451  Freedom of Expression and the Age of the Silve...    Journal Article
# 518                                 Setting Boundaries      Blog Postings
# 519                                 Setting Boundaries      Blog Postings
# 564                    Reference Guide on Neuroscience      Book, Section
# 565                    Reference Guide on Neuroscience      Book, Section
#
#     Contribution     Date  Year     Status  ... Abstract  \
# 127          NaN     2021  2021        NaN  ...      NaN
# 128          NaN     2021  2021        NaN  ...      NaN
# 185       Writer     2023  2023        NaN  ...      NaN
# 187       Writer     2023  2023        NaN  ...      NaN
# 450       Writer  2024-10  2024  Published  ...      NaN
# 451       Writer  2024-10  2024  Published  ...      NaN
# 518       Writer     2021  2021        NaN  ...      NaN
# 519       Writer     2021  2021        NaN  ...      NaN
# 564       Writer     2025  2025        NaN  ...      NaN
# 565       Writer     2025  2025        NaN  ...      NaN
#
#                                         Source Link(s)  \
# 127                                                NaN
# 128                                                NaN
# 185                                                NaN
# 187                                                NaN
# 450  https://heinonline-org.ezproxy.law.stanford.ed...
# 451  https://heinonline-org.ezproxy.law.stanford.ed...
# 518                                                NaN
# 519                                                NaN
# 564                                                NaN
# 565                                                NaN
#
#                                          Stanford Link  DOI PURL SSRN  \
# 127  https://law.stanford.edu/publications/processe...  NaN  NaN  NaN
# 128  https://law.stanford.edu/publications/processe...  NaN  NaN  NaN
# 185  https://law.stanford.edu/publications/recent-d...  NaN  NaN  NaN
# 187  https://law.stanford.edu/publications/recent-d...  NaN  NaN  NaN
# 450  https://law.stanford.edu/publications/freedom-...  NaN  NaN  NaN
# 451  https://law.stanford.edu/publications/freedom-...  NaN  NaN  NaN
# 518  https://law.stanford.edu/publications/setting-...  NaN  NaN  NaN
# 519  https://law.stanford.edu/publications/setting-...  NaN  NaN  NaN
# 564  https://law.stanford.edu/publications/referenc...  NaN  NaN  NaN
# 565  https://law.stanford.edu/publications/referenc...  NaN  NaN  NaN
#
#     In ORCID Corrected Designation is_exact_duplicate
# 127      NaN       NaN    Emeritus               True
# 128      NaN       NaN    Emeritus               True
# 185      NaN       NaN    Emeritus               True
# 187      NaN       NaN    Emeritus               True
# 450      NaN       NaN    Emeritus               True
# 451      NaN       NaN    Emeritus               True
# 518      NaN       NaN     Faculty               True
# 519      NaN       NaN     Faculty               True
# 564      NaN       NaN     Faculty               True
# 565      NaN       NaN     Faculty               True
#
# [10 rows x 32 columns]

# %%
dup_df['is_exact_duplicate'].value_counts()
# Out:
# is_exact_duplicate
# False    191
# True      75
# Name: count, dtype: int64

# %%
non_exact = dup_df[~dup_df['is_exact_duplicate']].copy()

print(non_exact.shape[0])

display(
    non_exact
    .sort_values(["ID", "Faculty Contributor", "Title"])
    .head(10)
)
# Out:
# 191
#             ID        Faculty Contributor Faculty Co-Authors/Editors  \
# 35    229380.0          Ablavsky, Gregory  Ouellette, Lisa Larrimore
# 1484  229380.0  Ouellette, Lisa Larrimore          Ablavsky, Gregory
# 508   229440.0          Gilson, Ronald J.                Brest, Paul
# 936   229440.0          Klausner, Michael                        NaN
# 1047  229445.0            Lemley, Mark A.          Malone, Philip R.
# 1079  229445.0          Malone, Philip R.                        NaN
# 220   232417.0       Donohue III, John J.                        NaN
# 1333  232417.0         Morantz, Alison D.                        NaN
# 1262  232841.0         Mello, Michelle M.            Sonne, James A.
# 1683  232841.0            Sonne, James A.                        NaN
#
#               Co-Authors                                              Title  \
# 35                   NaN  Selling Patents to Indian Tribes to Delay the ...
# 1484                 NaN  Selling Patents to Indian Tribes to Delay the ...
# 508        Wolfson, Mark  How Investors Can (and Can't) Create Social Value
# 936                  NaN  Brief for Corporate Law Professors As Amici Cu...
# 1047       Pearlman, Jef  Brief of Amici Curiae Law Professors and Publi...
# 1079                 NaN  Brief of Amici Curiae Law Professors and Publi...
# 220   Morantz, Alison D.  Brief of Amici Curiae Economists and Professor...
# 1333                 NaN  Brief of Amici Curiae Economists and Professor...
# 1262    Opel, Douglas J.  Vaccination without Litigation - Addressing Re...
# 1683                 NaN  Vaccination without Litigation - Addressing Re...
#
#      Publication Type Contribution        Date  Year     Status  ... Abstract  \
# 35    Journal Article       Writer  2018-01-02  2018  Published  ...      NaN
# 1484  Journal Article       Writer  2018-01-02  2018  Published  ...      NaN
# 508             Brief          NaN  2017-12-06  2017        NaN  ...      NaN
# 936             Brief          NaN  2017-12-06  2017  Published  ...      NaN
# 1047            Brief       Writer  2018-01-23  2018  Published  ...      NaN
# 1079            Brief          NaN  2018-01-23  2018        NaN  ...      NaN
# 220             Brief          NaN  2018-01-18  2018  Published  ...      NaN
# 1333            Brief          NaN  2018-01-18  2018        NaN  ...      NaN
# 1262  Journal Article       Writer  2018-03-01  2018  Published  ...      NaN
# 1683  Journal Article       Writer  2018-03-01  2018  Published  ...      NaN
#
#                                          Source Link(s)  \
# 35    https://jamanetwork.com/journals/jamainternalm...
# 1484  https://jamanetwork.com/journals/jamainternalm...
# 508                                                 NaN
# 936                                                 NaN
# 1047                                                NaN
# 1079                                                NaN
# 220                                                 NaN
# 1333                                                NaN
# 1262  https://www.nejm.org/doi/full/10.1056/NEJMp171...
# 1683  https://www.nejm.org/doi/full/10.1056/NEJMp171...
#
#                                           Stanford Link  DOI PURL SSRN  \
# 35    https://law.stanford.edu/publications/selling-...  NaN  NaN  NaN
# 1484  https://law.stanford.edu/publications/selling-...  NaN  NaN  NaN
# 508   https://law.stanford.edu/publications/brief-fo...  NaN  NaN  NaN
# 936   https://law.stanford.edu/publications/brief-fo...  NaN  NaN  NaN
# 1047  https://law.stanford.edu/publications/brief-of...  NaN  NaN  NaN
# 1079  https://law.stanford.edu/publications/brief-of...  NaN  NaN  NaN
# 220   https://law.stanford.edu/publications/brief-of...  NaN  NaN  NaN
# 1333  https://law.stanford.edu/publications/brief-of...  NaN  NaN  NaN
# 1262  https://law.stanford.edu/publications/vaccinat...  NaN  NaN  NaN
# 1683  https://law.stanford.edu/publications/vaccinat...  NaN  NaN  NaN
#
#      In ORCID Corrected       Designation is_exact_duplicate
# 35        NaN   checked           Faculty              False
# 1484  checked   checked           Faculty              False
# 508       NaN       NaN          Emeritus              False
# 936       NaN       NaN           Faculty              False
# 1047      NaN   checked           Faculty              False
# 1079      NaN       NaN  Clinical Faculty              False
# 220       NaN   checked           Faculty              False
# 1333      NaN       NaN           Faculty              False
# 1262      NaN   checked           Faculty              False
# 1683      NaN       NaN  Clinical Faculty              False
#
# [10 rows x 32 columns]

# %%
# Drop exact row duplicates across ALL columns
df_clean = df.drop_duplicates(keep="first").copy()

print("Before:", df.shape[0], "rows")
print("After :", df_clean.shape[0], "rows")
# Out:
# Before: 1927 rows
# After : 1889 rows

# %% [markdown]
# The exact duplicate rows are now removed.
# The other rows with same ID has small differences such as Faculty Contributor and Faculty Co-Author mismatched or titles including special characters.

# %%
# Recompute duplicate IDs on the cleaned frame
id_counts = df_clean["ID"].value_counts()
dup_ids = id_counts[id_counts > 1].index

dup_df = df_clean[df_clean["ID"].isin(dup_ids)].copy()

print("Number of rows with duplicate IDs (after exact dedupe):", dup_df.shape[0])
print("Number of duplicate IDs:", len(dup_ids))
# Out:
# Number of rows with duplicate IDs (after exact dedupe): 193
# Number of duplicate IDs: 91

# %% [markdown]
# ## Rule based Deduplication using AI
#
# Remove for exact duplicates, keep one only
#
# Keep row with Corrected = checked if only 1
#
# Else pass it to LLM to flag potential row to remove
#
# LLM follows the decision based on completeness and consistency

# %%
api_key = userdata.get('OPENAI_API_KEY')
if api_key is None:
    raise ValueError("No OPENAI_API_KEY secret found. Add it in Colab → Secrets sidebar.")

client = OpenAI(api_key=api_key)

cols_for_llm = [
    "ID",
    "Faculty Contributor",
    "Faculty Co-Authors/Editors",
    "Co-Authors",
    "Title",
    "Publication Type",
    "Contribution",
    "Date",
    "Status",
    "Serial Title",
    "Publisher",
    "Publication Title",
    "Editor(s)",
    "Citation",
    "ISBN",
    "ISSN",
    "Source Link(s)",
    "Stanford Link",
]

def choose_row_with_llm(group: pd.DataFrame) -> int:
    """
    Given a group of rows with the same ID (from df_clean) that has no
    unique 'Corrected == "checked"' row, ask the model which row index
    to KEEP (canonical). Returns the DataFrame index (int) of the chosen row.
    """

    rows = []
    for idx, row in group[cols_for_llm].iterrows():
        data = row.to_dict()
        data["row_index"] = int(idx)
        rows.append(data)

    prompt = f"""
You are helping deduplicate faculty publication records from Stanford Law.

All the rows below share the same internal ID and are candidate records for the same publication.
Each row has a unique 'row_index'.

Your task:
Select exactly ONE row to treat as the canonical record to KEEP.
Downstream, we will mark that row with "yes" in a 'remove' column and treat the others as candidates to drop.

Decision rules (apply in this order):
1. Prefer rows that are more complete:
   - Fewer null/empty values across fields is better.
   - Pay special attention to fields like Title, Date/Year, Publication Type, Serial Title, Status, Stanford Link, and Citation.
2. Prefer rows that are more internally consistent:
   - Date/Year, Status, and Citation should agree (e.g., no obviously impossible years).
   - Title and Serial Title should form a plausible legal publication (journal/book/etc.).
   - Stanford Link / URLs should look plausible and not clearly malformed.
3. Prefer rows with stronger identifiers or links:
   - Presence of a valid Stanford Link or other stable URL is a positive signal.
4. If there is still a tie:
   - Prefer the row with richer text (e.g., longer non-empty Title or Citation).
   - If still tied, choose the row with the lowest 'row_index'.

Output format:
Return ONLY valid JSON with the single row_index you choose to KEEP:

{{
  "canonical_row_index": <integer>
}}

Do not include any explanation or additional fields.

Here are the rows (JSON list):

{json.dumps(rows, ensure_ascii=False, indent=2)}
"""

    response = client.chat.completions.create(
        model="gpt-5-mini",
        messages=[{"role": "user", "content": prompt}]
    )

    content = response.choices[0].message.content
    result = json.loads(content)
    return int(result["canonical_row_index"])

# %%
df_clean["remove"] = "no"
llm_count = 0
skip_count = 0   # groups resolved without LLM

# Group by ID and decide which row to keep per group
for id_val, group in dup_df.groupby("ID"):
    corrected_mask = group["Corrected"].eq("checked")
    num_corrected = corrected_mask.sum()

    if num_corrected == 1:
        # Exactly one corrected row → keep that one, drop the others (no LLM call)
        keep_idx = group[corrected_mask].index[0]
        skip_count += 1
    else:
        # Either 0 or >1 corrected rows → call LLM to choose the single best row to KEEP
        keep_idx = choose_row_with_llm(group)
        llm_count += 1

    # First mark all rows in this ID group as "yes" (to be removed)
    df_clean.loc[group.index, "remove"] = "yes"

    # Then mark the chosen row as "no" (KEEP)
    df_clean.loc[keep_idx, "remove"] = "no"

print(f"LLM was used for {llm_count} ID groups.")
print(f"Skipped LLM for {skip_count} ID groups (exactly one corrected row).")
# Out:
# LLM was used for 61 ID groups.
# Skipped LLM for 30 ID groups (exactly one corrected row).

# %%
# Sanity check
checked = df_clean[
    (df_clean["Corrected"] == "checked") &
    (df_clean["remove"] == "yes")
]

print("Total rows with Corrected='checked' AND remove='yes':", len(checked))

checked["ID"].head()
# Out:
# Total rows with Corrected='checked' AND remove='yes': 37
# 114    494404.0
# 280    501086.0
# 296    384899.0
# 304    308137.0
# 325    485895.0
# Name: ID, dtype: float64

# %%
ids_to_check = [494404, 501086, 384899, 485895, 485899]

df_clean[df_clean["ID"].isin(ids_to_check)]
# Out:
#            ID      Faculty Contributor Faculty Co-Authors/Editors  \
# 113  494404.0              Belt, Rabia                        NaN
# 114  494404.0              Belt, Rabia                        NaN
# 279  485895.0  Engstrom, David Freeman     Engstrom, Nora Freeman
# 280  501086.0  Engstrom, David Freeman     Engstrom, Nora Freeman
# 284  485899.0  Engstrom, David Freeman     Engstrom, Nora Freeman
# 296  384899.0  Engstrom, David Freeman     Engstrom, Nora Freeman
# 322  501086.0   Engstrom, Nora Freeman    Engstrom, David Freeman
# 325  485895.0   Engstrom, Nora Freeman    Engstrom, David Freeman
# 327  485899.0   Engstrom, Nora Freeman    Engstrom, David Freeman
# 343  384899.0   Engstrom, Nora Freeman    Engstrom, David Freeman
#
#                                           Co-Authors  \
# 113                                              NaN
# 114                                              NaN
# 279                                              NaN
# 280                                              NaN
# 284  Gelbach, Jonah B.; Peters, Austin; Wen, Garrett
# 296                                              NaN
# 322                                              NaN
# 325                                              NaN
# 327  Gelbach, Jonah B.; Peters, Austin; Wen, Garrett
# 343                                              NaN
#
#                                                  Title Publication Type  \
# 113  Rabia Belt, Disability, Dignity, and Democracy...    Book, Section
# 114                 Disability, Dignity, and Democracy    Book, Section
# 279  Rethinking the Lawyers' Monopoly: Access to Ju...      Book, Whole
# 280           Envisioning the Future of Legal Services    Book, Section
# 284  Shedding Light on Secret Settlements: An Empir...  Journal Article
# 296        Legal Tech and the Litigation Playing Field    Book, Section
# 322           Envisioning the Future of Legal Services    Book, Section
# 325  Rethinking the Lawyers' Monopoly: Access to Ju...      Book, Whole
# 327  Shedding Light on Secret Settlements: An Empir...  Journal Article
# 343        Legal Tech and the Litigation Playing Field    Book, Section
#
#       Contribution        Date  Year       Status  ... Abstract  \
# 113         Writer        2025  2025  Forthcoming  ...      NaN
# 114         Writer        2025  2025  Forthcoming  ...      NaN
# 279  Editor,Writer     2025-09  2025    Published  ...      NaN
# 280         Writer     2025-09  2025    Published  ...      NaN
# 284         Writer     2025-01  2025    Published  ...      NaN
# 296         Writer        2023  2023    Published  ...      NaN
# 322         Writer     2025-09  2025    Published  ...      NaN
# 325  Editor,Writer     2025-09  2025    Published  ...      NaN
# 327         Writer     2025-01  2025    Published  ...      NaN
# 343         Writer  2023-02-20  2023    Published  ...      NaN
#
#                                         Source Link(s)  \
# 113                                                NaN
# 114                                                NaN
# 279                                                NaN
# 280                                                NaN
# 284  https://lawreview.uchicago.edu/print-archive/s...
# 296                                                NaN
# 322                                                NaN
# 325                                                NaN
# 327  https://lawreview.uchicago.edu/print-archive/s...
# 343                                                NaN
#
#                                          Stanford Link  \
# 113  https://law.stanford.edu/publications/rabia-be...
# 114  https://law.stanford.edu/publications/rabia-be...
# 279  https://law.stanford.edu/publications/rethinki...
# 280  https://law.stanford.edu/publications/envision...
# 284  https://law.stanford.edu/publications/shedding...
# 296  https://law.stanford.edu/publications/legal-te...
# 322  https://law.stanford.edu/publications/envision...
# 325  https://law.stanford.edu/publications/rethinki...
# 327  https://law.stanford.edu/publications/shedding...
# 343  https://law.stanford.edu/publications/legal-te...
#
#                                            DOI PURL SSRN In ORCID Corrected  \
# 113                                        NaN  NaN  NaN      NaN   checked
# 114                                        NaN  NaN  NaN      NaN   checked
# 279                                        NaN  NaN  NaN      NaN   checked
# 280                                        NaN  NaN  NaN      NaN   checked
# 284                                        NaN  NaN  NaN      NaN   checked
# 296  https://doi.org/10.1017/9781009255301.009  NaN  NaN      NaN   checked
# 322                                        NaN  NaN  NaN      NaN   checked
# 325                                        NaN  NaN  NaN      NaN   checked
# 327                                        NaN  NaN  NaN      NaN   checked
# 343  https://doi.org/10.1017/9781009255301.009  NaN  NaN      NaN   checked
#
#     Designation remove
# 113     Faculty     no
# 114     Faculty    yes
# 279     Faculty     no
# 280     Faculty    yes
# 284     Faculty     no
# 296     Faculty    yes
# 322     Faculty     no
# 325     Faculty    yes
# 327     Faculty    yes
# 343     Faculty     no
#
# [10 rows x 32 columns]

# %%
# 1) Drop rows marked for removal
df_clean.drop(df_clean.index[df_clean["remove"] == "yes"], inplace=True)

# 2) Total number of rows after removal
total_rows = len(df_clean)
print("Total rows after dedup:", total_rows)

# 3) Count duplicate IDs that still remain
id_counts = df_clean["ID"].value_counts()
dup_ids = id_counts[id_counts > 1].index
num_dup_ids = len(dup_ids)

print("Number of IDs that still have duplicates:", num_dup_ids)
# Out:
# Total rows after dedup: 1787
# Number of IDs that still have duplicates: 0

# %%
# Check for duplicates in other columns
cols_to_check = ["Title", "Citation", "Source Link(s)", "Stanford Link"]

for col in cols_to_check:
    dup_rows = df_clean[df_clean.duplicated(subset=[col], keep=False) & df_clean[col].notna()]

    num_dup_values = dup_rows[col].nunique()
    num_dup_rows = dup_rows.shape[0]

    print(f"\n=== Column: {col} ===")
    print(f"Number of distinct duplicated values: {num_dup_values}")
    print(f"Number of rows involved in those duplicates: {num_dup_rows}")

    if num_dup_rows > 0:
        print("Sample duplicate groups:")
        display(
            dup_rows
            .sort_values(col)
            [[col, "ID", "Faculty Contributor", "Year"]]
            .head(10)
        )
# Out:
# === Column: Title ===
# Number of distinct duplicated values: 67
# Number of rows involved in those duplicates: 145
# Sample duplicate groups:
#                                                  Title        ID  \
# 811  A Pro-Feminist Life: Sherry Colb and Abortion ...  500801.0
# 824  A Pro-Feminist Life: Sherry Colb and Abortion ...  449820.0
# 922                              A Sober Look at SPACs  403738.0
# 932                              A Sober Look at SPACs  404415.0
# 929                              A Sober Look at SPACs  383968.0
# 638  Abandoned and Split But Never Reversed: Borak ...  449660.0
# 639  Abandoned and Split But Never Reversed: Borak ...  497821.0
# 640  Abandoned and Split But Never Reversed: Borak ...  448620.0
# 991                           Abandoning Trade Secrets  329348.0
# 982                           Abandoning Trade Secrets  404579.0
#
#       Faculty Contributor  Year
# 811     Karlan, Pamela S.  2024
# 824     Karlan, Pamela S.  2023
# 922     Klausner, Michael  2022
# 932     Klausner, Michael  2020
# 929     Klausner, Michael  2021
# 638  Grundfest, Joseph A.  2023
# 639  Grundfest, Joseph A.  2023
# 640  Grundfest, Joseph A.  2022
# 991       Lemley, Mark A.  2021
# 982       Lemley, Mark A.  2022
# === Column: Citation ===
# Number of distinct duplicated values: 8
# Number of rows involved in those duplicates: 16
# Sample duplicate groups:
#                                                Citation        ID  \
# 571   Amander Clark, Eric Topol, Hank Greely, Salim ...  514279.0
# 573   Amander Clark, Eric Topol, Hank Greely, Salim ...  514272.0
# 1797  Barton H. Thompson, Jr., Liquid Asset: How Bus...  445849.0
# 1798  Barton H. Thompson, Jr., Liquid Asset: How Bus...  448073.0
# 1277  Bernadette Meyler, Bernadette Meyler Staging t...  447842.0
# 1280  Bernadette Meyler, Bernadette Meyler Staging t...  407098.0
# 379   George Fisher, Beware Euphoria: The Moral Root...  496954.0
# 380   George Fisher, Beware Euphoria: The Moral Root...  448342.0
# 1576  Kathleen G. Noonan, Jonathan C. Lipson & Willi...  285902.0
# 1577  Kathleen G. Noonan, Jonathan C. Lipson & Willi...       NaN
#
#              Faculty Contributor  Year
# 571             Greely, Henry T.  2024
# 573             Greely, Henry T.  2024
# 1797  Thompson, Barton H. "Buzz"  2023
# 1798  Thompson, Barton H. "Buzz"  2023
# 1277          Meyler, Bernadette  2023
# 1280          Meyler, Bernadette  2022
# 379               Fisher, George  2024
# 380               Fisher, George  2023
# 1576              Simon, William  2019
# 1577              Simon, William  2019
# === Column: Source Link(s) ===
# Number of distinct duplicated values: 17
# Number of rows involved in those duplicates: 35
# Sample duplicate groups:
#                                          Source Link(s)        ID  \
# 1063  https://books.google.com/books/about/Deliberat...  308215.0
# 1062  https://books.google.com/books/about/Deliberat...  308213.0
# 984                 https://clause8publishing.com/ipnta  403388.0
# 988                 https://clause8publishing.com/ipnta  403225.0
# 1035     https://searchworks.stanford.edu/view/13180472  285505.0
# 1033     https://searchworks.stanford.edu/view/13180472  285507.0
# 1026     https://searchworks.stanford.edu/view/13180472  285489.0
# 462      https://searchworks.stanford.edu/view/13736857  383918.0
# 475      https://searchworks.stanford.edu/view/13736857  383916.0
# 90    https://stanfordmag.org/contents/what-should-f...  283575.0
#
#         Faculty Contributor  Year
# 1063     MacCoun, Robert J.  2021
# 1062     MacCoun, Robert J.  2021
# 984         Lemley, Mark A.  2022
# 988         Lemley, Mark A.  2022
# 1035        Lemley, Mark A.  2019
# 1033        Lemley, Mark A.  2019
# 1026        Lemley, Mark A.  2019
# 462   Friedman, Lawrence M.  2021
# 475   Friedman, Lawrence M.  2020
# 90     Banks, Ralph Richard  2019
# === Column: Stanford Link ===
# Number of distinct duplicated values: 1
# Number of rows involved in those duplicates: 2
# Sample duplicate groups:
#                                           Stanford Link        ID  \
# 1576  https://law.stanford.edu/publications/reformin...  285902.0
# 1577  https://law.stanford.edu/publications/reformin...       NaN
#
#      Faculty Contributor  Year
# 1576      Simon, William  2019
# 1577      Simon, William  2019

# %%
df["Italics"].equals(df["Corrected"]) #The italics column can be removed
# Out:
# True

# %%
print("Shape (rows, columns):", df_clean.shape)
# Out:
# Shape (rows, columns): (1787, 32)

# %%
print(df_clean.columns.tolist())
# Out:
# ['ID', 'Faculty Contributor', 'Faculty Co-Authors/Editors', 'Co-Authors', 'Title', 'Publication Type', 'Contribution', 'Date', 'Year', 'Status', 'Serial Title', 'Publisher', 'Publication Title', 'Editor(s)', 'Citation', 'Italics', 'Volume', 'Issue', 'Pages', 'Edition', 'ISBN', 'ISSN', 'Abstract', 'Source Link(s)', 'Stanford Link', 'DOI', 'PURL', 'SSRN', 'In ORCID', 'Corrected', 'Designation', 'remove']

# %% [markdown]
# ## Data Curation using Crossref

# %%
from difflib import SequenceMatcher

TARGET_COLS = [
    "Source Link(s)",
    "DOI",
    "Volume",
    "Issue",
    "Pages",
    "Edition",
    "ISBN",
    "ISSN",
]

CROSSREF_API_BASE = "https://api.crossref.org/works"


def query_crossref_by_title(title, author=None, year=None, rows=5):
    """
    Query Crossref using title (+ optional author/year).
    Returns a list of candidate items (possibly empty).
    """
    if not isinstance(title, str) or not title.strip():
        return []

    params = {
        "query.title": title,
        "rows": rows,
    }

    if isinstance(author, str) and author.strip():
        params["query.author"] = author

    if year is not None:
      y = int(year)
      params["filter"] = f"from-pub-date:{y}-01-01,until-pub-date:{y}-12-31"

    try:
        r = requests.get(CROSSREF_API_BASE, params=params, timeout=10)
        r.raise_for_status()
    except Exception as e:
        print("Crossref request error:", e)
        return []

    data = r.json()
    return data.get("message", {}).get("items", [])


def pick_best_crossref_match(title, items, min_ratio=0.8):
    """
    Pick the Crossref item whose title best matches the given title.
    Returns (best_item, best_score) where best_item may be None.
    """
    if not items:
        return None, 0.0

    title_norm = title.strip().lower()
    best_item = None
    best_score = 0.0

    for item in items:
        item_titles = item.get("title", []) or []
        if not item_titles:
            continue
        item_title = item_titles[0].strip().lower()
        ratio = SequenceMatcher(None, title_norm, item_title).ratio()
        if ratio > best_score:
            best_score = ratio
            best_item = item

    if best_score < min_ratio:
        return None, best_score

    return best_item, best_score


def extract_metadata_from_crossref(item):
    """
    Extract fields and returns a dict keyed by our column names.
    """
    if item is None:
        return {}

    updates = {}

    doi = item.get("DOI")
    if doi:
        updates["DOI"] = doi

    url = item.get("URL")
    if url:
        updates["Source Link(s)"] = url

    vol = item.get("volume")
    if vol:
        updates["Volume"] = str(vol)

    issue = item.get("issue")
    if issue:
        updates["Issue"] = str(issue)

    pages = item.get("page")
    if pages:
        updates["Pages"] = str(pages)

    issn_list = item.get("ISSN", []) or []
    if issn_list:
        updates["ISSN"] = issn_list[0]

    isbn_list = item.get("ISBN", []) or []
    if isbn_list:
        updates["ISBN"] = isbn_list[0]

    edition = item.get("edition-number") or item.get("edition")
    if edition:
        updates["Edition"] = str(edition)


    return updates

# %%
df_enriched = df_clean.copy()

# make target cols string dtype
for col in TARGET_COLS:
    if col in df_enriched.columns:
        df_enriched[col] = df_enriched[col].astype("string")

df_enriched["Flagged"] = "no"

# 1) Full set of rows that have at least one missing target field
rows_to_enrich = df_enriched[df_enriched[TARGET_COLS].isna().any(axis=1)]
print("Rows with at least one missing target field:", rows_to_enrich.shape[0])

# 2) Subset of 100 rows we will actually hit Crossref with
rows_subset = rows_to_enrich.head(100).copy()
print("Rows to enrich now:", rows_subset.shape[0])

enriched = 0
enriched_indices = []

for idx, row in rows_subset.iterrows():
    title = row["Title"]
    year = int(row["Year"])
    faculty = row["Faculty Contributor"]  # "Lastname, Firstname"
    author = faculty.split(",")[0].strip()

    items = query_crossref_by_title(title, author=author, year=year, rows=5)
    best_item, score = pick_best_crossref_match(title, items, min_ratio=0.8)

    if best_item is None:
        continue

    updates = extract_metadata_from_crossref(best_item)
    if not updates:
        continue

    row_enriched = False

    for col, val in updates.items():
        if col not in df_enriched.columns:
            continue

        current = df_enriched.at[idx, col]
        current_str = None if pd.isna(current) else str(current).strip()

        if current_str is None or current_str == "":
            df_enriched.at[idx, col] = None if val is None else str(val)
            row_enriched = True

    if row_enriched:
        enriched += 1
        enriched_indices.append(idx)

print("Rows successfully enriched from Crossref from 100 subset", enriched)
# Out:
# Rows with at least one missing target field: 1787
# Rows to enrich now: 100
# Rows successfully enriched from Crossref from 100 subset 23

# %% [markdown]
# Checked with 100 rows due to rate limits on free API. Successful in filling 23% of the rows
#
# Compare before and after to see the differences

# %%
cols_to_check = [
    "Title", "Year", "Faculty Contributor",
    "DOI", "ISSN", "Volume", "Issue", "Pages", "Source Link(s)"
]

if enriched_indices:
    sample_indices = enriched_indices[:10]

    with pd.option_context("display.max_colwidth", None,
                       "display.width", None,
                       "display.max_columns", None):
      print("Before (df_clean) – sample of enriched rows:")
      display(df_clean.loc[sample_indices, cols_to_check])

      print("After (df_enriched) – same sample:")
      display(df_enriched.loc[sample_indices, cols_to_check])
else:
    print("No rows were enriched in this sample.")
# Out:
# Before (df_clean) – sample of enriched rows:
#                                                                                              Title  \
# 2                                   The Original Meaning of Commerce in the Indian Commerce Clause
# 4                                                                       Akhil Amar's Unusable Past
# 6                          Too Much History: Castro-Huerta and the Problem of Change in Indian Law
# 11                   Beyond the Indian Commerce Clause: Robert Natelson's Problematic "Cite Check"
# 18                                  Credit Nation: Property Laws and Institutions in Early America
# 20                        Murder in the Shenandoah: Making Law Sovereign in Revolutionary Virginia
# 21  Of One Mind and of One Government: The Rise and Fall of the Creek Nation in the Early Republic
# 27  Species of Sovereignty: Native Nationhood, the United States, and International Law, 1783-1795
# 35                     Selling Patents to Indian Tribes to Delay the Market Entry of Generic Drugs
# 38                                                                                          Racism
#
#     Year  Faculty Contributor  DOI ISSN Volume Issue    Pages  \
# 2   2024    Ablavsky, Gregory  NaN  NaN     56   NaN     1013
# 4   2023    Ablavsky, Gregory  NaN  NaN    121   NaN     1119
# 6   2023    Ablavsky, Gregory  NaN  NaN   2022   NaN      293
# 11  2022    Ablavsky, Gregory  NaN  NaN    NaN   NaN      NaN
# 18  2021    Ablavsky, Gregory  NaN  NaN     61   NaN      340
# 20  2020    Ablavsky, Gregory  NaN  NaN     40   NaN      752
# 21  2020    Ablavsky, Gregory  NaN  NaN     86   NaN      143
# 27  2019    Ablavsky, Gregory  NaN  NaN    106     3  591–613
# 35  2018    Ablavsky, Gregory  NaN  NaN    178   NaN      179
# 38  2025  Achiume, E. Tendayi  NaN  NaN    NaN   NaN      NaN
#
#                                                                Source Link(s)
# 2                                                                         NaN
# 4                                                                         NaN
# 6                                                                         NaN
# 11                                                                        NaN
# 18                                                                        NaN
# 20                                        https://muse.jhu.edu/article/772960
# 21                                        https://muse.jhu.edu/article/748749
# 27                     https://academic.oup.com/jah/article/106/3/591/5628951
# 35  https://jamanetwork.com/journals/jamainternalmedicine/fullarticle/2666791
# 38                                                                        NaN
# After (df_enriched) – same sample:
#                                                                                              Title  \
# 2                                   The Original Meaning of Commerce in the Indian Commerce Clause
# 4                                                                       Akhil Amar's Unusable Past
# 6                          Too Much History: Castro-Huerta and the Problem of Change in Indian Law
# 11                   Beyond the Indian Commerce Clause: Robert Natelson's Problematic "Cite Check"
# 18                                  Credit Nation: Property Laws and Institutions in Early America
# 20                        Murder in the Shenandoah: Making Law Sovereign in Revolutionary Virginia
# 21  Of One Mind and of One Government: The Rise and Fall of the Creek Nation in the Early Republic
# 27  Species of Sovereignty: Native Nationhood, the United States, and International Law, 1783-1795
# 35                     Selling Patents to Indian Tribes to Delay the Market Entry of Generic Drugs
# 38                                                                                          Racism
#
#     Year  Faculty Contributor                              DOI       ISSN  \
# 2   2024    Ablavsky, Gregory             10.2139/ssrn.4911164  1556-5068
# 4   2023    Ablavsky, Gregory         10.36644/mlr.121.6.akhil  1939-8557
# 6   2023    Ablavsky, Gregory                   10.1086/724831  0081-9557
# 11  2022    Ablavsky, Gregory             10.2139/ssrn.4244353  1556-5068
# 18  2021    Ablavsky, Gregory             10.1093/ajlh/njab014  0002-9319
# 20  2020    Ablavsky, Gregory            10.1353/jer.2020.0109  1553-0620
# 21  2020    Ablavsky, Gregory            10.1353/soh.2020.0046  2325-6893
# 27  2019    Ablavsky, Gregory            10.1093/jahist/jaz503  0021-8723
# 35  2018    Ablavsky, Gregory  10.1001/jamainternmed.2017.7463  2168-6106
# 38  2025  Achiume, E. Tendayi      10.4337/9781802204155.00078       <NA>
#
#    Volume  Issue    Pages  \
# 2      56   <NA>     1013
# 4     121  121.6     1119
# 6    2022   <NA>      293
# 11   <NA>   <NA>     <NA>
# 18     61      3      340
# 20     40      4      752
# 21     86      1      143
# 27    106      3  591–613
# 35    178      2      179
# 38   <NA>   <NA>  423-428
#
#                                                                Source Link(s)
# 2                                        https://doi.org/10.2139/ssrn.4911164
# 4                                    https://doi.org/10.36644/mlr.121.6.akhil
# 6                                              https://doi.org/10.1086/724831
# 11                                       https://doi.org/10.2139/ssrn.4244353
# 18                                       https://doi.org/10.1093/ajlh/njab014
# 20                                        https://muse.jhu.edu/article/772960
# 21                                        https://muse.jhu.edu/article/748749
# 27                     https://academic.oup.com/jah/article/106/3/591/5628951
# 35  https://jamanetwork.com/journals/jamainternalmedicine/fullarticle/2666791
# 38                                https://doi.org/10.4337/9781802204155.00078

# %%
print("Shape (rows, columns):", df_enriched.shape)
# Out:
# Shape (rows, columns): (1787, 33)

# %% [markdown]
# ## Bluebook Citation Suggestor
#
# LLM finds potential issues and suggests the bluebook style formatted citation.
#
# This requires heavy manual reviews
#
# Better to use 3rd party tools if available and legal to use

# %%
def analyze_citation_bluebook(citation: str):
    """
    For a given citation string, ask an LLM:
    - What (if any) issues it has w.r.t. Bluebook style.
    - A suggested Bluebook-style citation.

    Returns (issues_text_or_None, suggested_citation_or_None).
    """
    if pd.isna(citation) or not str(citation).strip():
        return None, None

    citation_str = str(citation).strip()

    system_msg = (
        "You are an expert in Bluebook legal citation format. "
        "Given a citation string, identify any issues with Bluebook compliance "
        "(abbreviations, ordering, punctuation, missing fields, etc.). "
        "Then provide a corrected Bluebook-style citation. "
        "Do NOT invent new works; use only the information present in the input."
    )

    user_prompt = (
        "Input citation:\n\n"
        f"{citation_str}\n\n"
        "Return ONLY JSON using this schema:\n"
        "{\n"
        '  "issues": ["short issue description 1", "short issue description 2", ...],\n'
        '  "suggested_citation": "the citation rewritten in Bluebook style"\n'
        "}\n"
        "If the citation already looks acceptable in Bluebook, return an empty list for "
        '"issues" and you may return the original citation as suggested_citation.\n'
    )

    resp = client.chat.completions.create(
        model="gpt-5-mini",
        messages=[
            {"role": "system", "content": system_msg},
            {"role": "user", "content": user_prompt},
        ]
    )

    content = resp.choices[0].message.content

    try:
        data = json.loads(content)
    except json.JSONDecodeError:
        return "LLM response not valid JSON", None

    issues = data.get("issues", [])
    suggested = data.get("suggested_citation", "").strip() or None

    if not issues:
        return None, None  # no issues, no suggested-citation override

    issues_text = "; ".join(issues)
    return issues_text, suggested

# %%
df_enriched["Issue in Citation"] = pd.NA
df_enriched["Suggested Bluebook Citation"] = pd.NA

subset = df_enriched[df_enriched["Citation"].notna()].head(5)

for idx, cit in subset["Citation"].items():
    issues, suggestion = analyze_citation_bluebook(cit)

    # Column 1: 'Issue in Citation' – either issue text or None
    df_enriched.at[idx, "Issue in Citation"] = issues

    # Column 2: 'Suggested Bluebook Citation'
    # Only fill when there is an issue
    if issues is not None and suggestion is not None:
        df_enriched.at[idx, "Suggested Bluebook Citation"] = suggestion
    else:
        # Already acceptable → leave blank / NA
        df_enriched.at[idx, "Suggested Bluebook Citation"] = pd.NA

# Quick check: show only rows where an issue was found
with pd.option_context("display.max_colwidth", None,
                       "display.width", None,
                       "display.max_columns", None):
  display(
      df_enriched[
          df_enriched["Issue in Citation"].notna()
      ][["Citation", "Issue in Citation", "Suggested Bluebook Citation"]]
      .head(5)
  )
# Out:
#                                                                                                                                                                                                                                    Citation  \
# 0                                                                                                    Gregory Ablavsky, Speculation Nation: Land Mania in the Revolutionary American Republic, 129 Aᴍ. Hɪꜱᴛ. Rᴇᴠ. 1837 (2024) (book review).
# 1                                                                                                              Fᴇʟɪx S. Cᴏʜᴇɴ, Cᴏʜᴇɴ'ꜱ Hᴀɴᴅʙᴏᴏᴋ ᴏꜰ Fᴇᴅᴇʀᴀʟ Iɴᴅɪᴀɴᴀ Lᴀᴡ (Gregory Ablavsky, Bethany R. Berger & Maggie Blackhawk eds., 2024).
# 2                                                                                                                           Gregory Ablavsky, The Original Meaning of Commerce in the Indian Commerce Clause, 56 Cᴏɴɴ. L. Rᴇᴠ. 1013 (2024).
# 3  Gregory Ablavsky, Clarence Thomas Went After My Work. His Criticisms Reveal a Disturbing Fact About Originalism, Sʟᴀᴛᴇ (June 20, 2023), https://slate.com/news-and-politics/2023/06/clarence-thomas-indian-law-originalism-history.html.
# 4                                                                                                                                                Gregory Ablavsky, Akhil Amar's Unusable Past, 121 Mɪᴄʜ. L. Rᴇᴠ. 1119 (2023) (book review).
#
#                                                                                                                                                                                                                                                                                                                                                                Issue in Citation  \
# 0                     Journal abbreviation uses special/small-cap characters; use standard Bluebook abbreviation 'Am. Hist. Rev.'; Book title should be italicized in Bluebook formatting; Possible misattribution: citation lists Gregory Ablavsky as the author of the review; if this is a review of Ablavsky's book, the reviewer's name (not the book author) should appear
# 1                                                                                                                                      Uses stylized Unicode small caps and special characters instead of ordinary letters; Uses a nonstandard/special-character apostrophe in "Cᴏʜᴇɴ'ꜱ"; Unnecessary comma after "eds." before the year (Bluebook style uses e.g., "eds. 2024")
# 2                                                                                                                                                                                                                                          Journal abbreviation uses nonstandard/special characters (e.g., 'Cᴏɴɴ. L. Rᴇᴠ.'); Use standard Bluebook abbreviation: 'Conn. L. Rev.'
# 3  Periodical title uses Unicode small-caps 'Sʟᴀᴛᴇ' rather than normal 'Slate'.; Bluebook calls for the periodical title to be presented (typically in italic type) — here it appears plain/special-case formatted.; Trailing punctuation after the URL (final period) can interfere with link copying; Bluebook citations with URLs typically do not include a terminal period.
# 4                                                                                                                                                             Journal title uses nonstandard/special-character capitalization (Mɪᴄʜ. L. Rᴇᴠ.) instead of the Bluebook abbreviation; Journal abbreviation should be rendered as 'Mich. L. Rev.' with standard periods and spacing
#
#                                                                                                                                                                                                                Suggested Bluebook Citation
# 0                                                                                                   Gregory Ablavsky, Speculation Nation: Land Mania in the Revolutionary American Republic, 129 Am. Hist. Rev. 1837 (2024) (book review).
# 1                                                                                                               Felix S. Cohen, Cohen's Handbook of Federal Indian Law (Gregory Ablavsky, Bethany R. Berger & Maggie Blackhawk eds. 2024).
# 2                                                                                                                          Gregory Ablavsky, The Original Meaning of Commerce in the Indian Commerce Clause, 56 Conn. L. Rev. 1013 (2024).
# 3  Gregory Ablavsky, Clarence Thomas Went After My Work. His Criticisms Reveal a Disturbing Fact About Originalism, Slate (June 20, 2023), https://slate.com/news-and-politics/2023/06/clarence-thomas-indian-law-originalism-history.html
# 4                                                                                                                                               Gregory Ablavsky, Akhil Amar's Unusable Past, 121 Mich. L. Rev. 1119 (2023) (book review).

# %% [markdown]
# Only ran for few samples to keep API cost low and potential Colab timeout issues at times. It can be ran on the full dataset later
#
# ## Evaluate Metadata using Citation
#
# Checks whether metadata and citation matches and lists potential issues for reviewer
#
# AI is helpful in parsing and doing similarity checks while flagging issues

# %%
def evaluate_citation_vs_metadata(row: pd.Series):
    """
    Use LLM to decide if Citation matches key metadata.
    Returns: (matches_metadata: bool, issue_text_or_None)
    """
    citation = row.get("Citation", None)
    if pd.isna(citation) or not str(citation).strip():
        # No citation text at all → treat as not matching
        return False, "Missing citation text"

    payload = {
        "faculty_contributor": str(row.get("Faculty Contributor", "")),
        "Co-Authors": str(row.get("Co-Authors", "")),
        "title": str(row.get("Title", "")),
        "publication_type": str(row.get("Publication Type", "")),
        "year": int(row.get("Year")) if pd.notna(row.get("Year")) else None,
        "volume": str(row.get("Volume", "")) if pd.notna(row.get("Volume", "")) else "",
        "issue": str(row.get("Issue", "")) if pd.notna(row.get("Issue", "")) else "",
        "pages": str(row.get("Pages", "")) if pd.notna(row.get("Pages", "")) else "",
        "edition": str(row.get("Edition", "")) if pd.notna(row.get("Edition", "")) else "",
        "citation": str(citation),
    }

    system_msg = (
        "You are an expert legal bibliographer who understands Bluebook citation rules. "
        "You are given structured metadata for a publication and a citation string. "
        "Your job is ONLY to compare them for internal consistency. "
        "Do NOT look up external information. Do NOT guess missing facts. "
        "Treat abbreviated names/journal titles as matching if they clearly refer to the same person/journal."
    )

    user_prompt = f"""
Here is the metadata for a publication (JSON):

{json.dumps(payload, ensure_ascii=False, indent=2)}

Compare this metadata to the citation field (the 'citation' property).

Check:
- Does the citation appear to describe the same work as the metadata?
- Are there any clear conflicts in:
  * author (faculty_contributor),
  * title,
  * year,
  * volume / issue / pages / edition (when present),
  * publication type (article vs book vs chapter vs journal, etc.)?

Ignore minor punctuation or spacing differences.

Return ONLY JSON in this format:
{{
  "matches_metadata": true or false,
  "issues": ["short explanation of each issue you see, if any"]
}}
"""

    resp = client.chat.completions.create(
        model="gpt-5-mini",
        messages=[
            {"role": "system", "content": system_msg},
            {"role": "user", "content": user_prompt},
        ]
    )

    content = resp.choices[0].message.content

    try:
        data = json.loads(content)
    except json.JSONDecodeError:
        return False, "LLM response not valid JSON"

    matches = bool(data.get("matches_metadata", False))
    issues_list = data.get("issues", []) or []

    if matches:
        return True, None

    issue_text = "; ".join(issues_list) if issues_list else "Citation and metadata appear inconsistent"
    return False, issue_text

# %%
df_enriched["matches_metadata"] = False
df_enriched["metadat_issues"] = pd.NA

subset = df_enriched[df_enriched["Citation"].notna()].head(20)

for idx, row in subset.iterrows():
    matches, issue_text = evaluate_citation_vs_metadata(row)
    df_enriched.at[idx, "matches_metadata"] = matches

    if not matches and issue_text:
        df_enriched.at[idx, "metadat_issues"] = issue_text
    else:
        df_enriched.at[idx, "metadat_issues"] = pd.NA

display(df_enriched[["Faculty Contributor", "Title", "Year", "Citation", "matches_metadata", "metadat_issues"]].head(5))
# Out:
#   Faculty Contributor                                              Title  \
# 0   Ablavsky, Gregory  Speculation Nation: Land Mania in the Revoluti...
# 1   Ablavsky, Gregory             Cohen's Handbook of Federal Indian Law
# 2   Ablavsky, Gregory  The Original Meaning of Commerce in the Indian...
# 3   Ablavsky, Gregory  Clarence Thomas Went After My Work. His Critic...
# 4   Ablavsky, Gregory                         Akhil Amar's Unusable Past
#
#    Year                                           Citation  matches_metadata  \
# 0  2024  Gregory Ablavsky, Speculation Nation: Land Man...              True
# 1  2024  Fᴇʟɪx S. Cᴏʜᴇɴ, Cᴏʜᴇɴ'ꜱ Hᴀɴᴅʙᴏᴏᴋ ᴏꜰ Fᴇᴅᴇʀᴀʟ Iɴ...             False
# 2  2024  Gregory Ablavsky, The Original Meaning of Comm...              True
# 3  2023  Gregory Ablavsky, Clarence Thomas Went After M...              True
# 4  2023  Gregory Ablavsky, Akhil Amar's Unusable Past, ...              True
#
#                                       metadat_issues
# 0                                               <NA>
# 1  Title mismatch: metadata title is "Cohen's Han...
# 2                                               <NA>
# 3                                               <NA>
# 4                                               <NA>

# %% [markdown]
# Tested on a subset of data.
#
# This is useful in flagging errors and mistakes in Data Collection step
